# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("reg.csv")
sum1,sum2=0,0
x="x"
y="y"
d1=data.x
d2=data.y
x1=d1.mean()
y1=d2.mean()
for i in range(d1.count()):
    sum1=sum1+(((d1[i])-x1)*((d2[i])-y1))
for i in range(d1.count()):
    sum2+=((d1[i])-x1)**2
b1=sum1/sum2
# for i,j in zip(d1,d2):
#     a,b=i,j
# a,b=d1[1],d2[1]
b0=y1-b1*x1    
print("The Expression that is taken is y=",b0,"+",b1,"x")
a=int(input("Enter x value :"))
Z=b0+b1*a
z=[b0+b1*d1[i] for i in range(len(data))]
print("The Value of y Through regression is :",Z)

plt.scatter(d1,d2,s=25 )
plt.plot(d1,z)

plt.show()
# Out:
# The Expression that is taken is y= 1.2363636363636363 + 1.1696969696969697 x
# Enter x value :4
# The Value of y Through regression is : 5.915151515151515
